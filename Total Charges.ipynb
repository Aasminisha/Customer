# %%
import pandas as pd
cus=pd.read_csv("D:/Vcodez Datasets/Customer.csv")
cus.head()
# Out:
#    Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 0           1  8260-NGFNY    One  Month-to-month               No
# 1           2  2359-QWQUL     39        One year              Yes
# 2           3  6598/RFFVI      2        One year               No
# 3           4  IXSTS-8780      6  Month-to-month              Yes
# 4           5  2674/MIAHT   Four  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0             Mailed check            25.2         25.20  Female
# 1  Credit card (automatic)           104.7       4134.85  Female
# 2  Credit card (automatic)            19.3         28.30    Male
# 3         Electronic check            90.1        521.30  Female
# 4             Mailed check            80.3        324.20  Female
#
#    SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 0            0.0  ...           No  No phone service             DSL
# ...

# %%
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus["MonthlyCharges"]=cus["MonthlyCharges"].fillna(0)
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus["SeniorCitizen"]=cus["SeniorCitizen"].fillna(0)
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        15
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus[cus["TotalCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 13           14  2452-MRMZF     72        Two year              Yes
# 41           42  4910-AQFFX      9  Month-to-month              Yes
# 67           68  7605-BDWDC     31        Two year              Yes
# 69           70  4759-TRPLW   1008  Month-to-month               No
# 79           80  8148-BPLZQ     34  Month-to-month              Yes
# 92           93  5201-CBWYG     62        One year               No
# 97           98  1785-BPHTP     28  Month-to-month               No
# 118         119  5712-AHQNN     43  Month-to-month              Yes
# 121         122  3694-GLTJM      5  Month-to-month              Yes
# 135         136  3261-CQXOL     71        Two year               No
# 139         140  6447-GORXK     31  Month-to-month               No
# 152         153  1976-AZZPJ      7  Month-to-month               No
# 182         183  7932-WPTDS    One  Month-to-month              Yes
# ...

# %%
cus.loc[(cus["Contract"]=="Month-to-month")&
        (cus["PaperlessBilling"].isin(["Yes","No"]))&
        (cus["PhoneService"].isin(["Yes","No"]))&
        (cus["MultipleLines"].isin(["Yes","No"])),"TotalCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        8
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["TotalCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 13           14  2452-MRMZF     72        Two year              Yes
# 67           68  7605-BDWDC     31        Two year              Yes
# 92           93  5201-CBWYG     62        One year               No
# 135         136  3261-CQXOL     71        Two year               No
# 139         140  6447-GORXK     31  Month-to-month               No
# 152         153  1976-AZZPJ      7  Month-to-month               No
# 182         183  7932-WPTDS    One  Month-to-month              Yes
# 201         202  7080-TNUWP     70        One year              Yes
#
#                  PaymentMethod  MonthlyCharges TotalCharges  gender  \
# 13     Credit card (automatic)           25.70          NaN  Female
# 67   Bank transfer (automatic)           49.85          NaN  Female
# 92   Bank transfer (automatic)           24.80          NaN    Male
# 135  Bank transfer (automatic)           25.45          NaN  Female
# ...

# %%
cus.loc[(cus["Contract"]=="Two year")&
        (cus["PaperlessBilling"].isin(["Yes","No"]))&
        (cus["PhoneService"].isin(["Yes","No"]))&
        (cus["MultipleLines"].isin(["Yes","No"])),"TotalCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        6
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus.loc[(cus["Contract"]=="One year")&
        (cus["PaperlessBilling"].isin(["Yes","No"]))&
        (cus["PhoneService"].isin(["Yes","No"]))&
        (cus["MultipleLines"].isin(["Yes","No"])),"TotalCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        4
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["TotalCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 67           68  7605-BDWDC     31        Two year              Yes
# 139         140  6447-GORXK     31  Month-to-month               No
# 152         153  1976-AZZPJ      7  Month-to-month               No
# 182         183  7932-WPTDS    One  Month-to-month              Yes
#
#                  PaymentMethod  MonthlyCharges TotalCharges  gender  \
# 67   Bank transfer (automatic)           49.85          NaN  Female
# 139    Credit card (automatic)           25.00          NaN    Male
# 152               Mailed check           34.20          NaN    Male
# 182           Electronic check           24.80          NaN  Female
#
#      SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 67             0.0  ...           No  No phone service             DSL
# 139            0.0  ...           No  No phone service             DSL
# ...

# %%
cus.loc[(cus["Contract"]=="Month-to-month")&
        (cus["PaperlessBilling"].isin(["Yes","No"]))&
        (cus["PhoneService"].isin(["No"]))&
        (cus["MultipleLines"].isin(["No phone sservic])),"TotalCharges"]="0.0"
cus
cus.isnull().sum()
