# %%
import pandas as pd
cus=pd.read_csv("D:/Vcodez Datasets/Customer.csv")
cus.head()
# Out:
#    Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 0           1  8260-NGFNY    One  Month-to-month               No
# 1           2  2359-QWQUL     39        One year              Yes
# 2           3  6598/RFFVI      2        One year               No
# 3           4  IXSTS-8780      6  Month-to-month              Yes
# 4           5  2674/MIAHT   Four  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0             Mailed check            25.2         25.20  Female
# 1  Credit card (automatic)           104.7       4134.85  Female
# 2  Credit card (automatic)            19.3         28.30    Male
# 3         Electronic check            90.1        521.30  Female
# 4             Mailed check            80.3        324.20  Female
#
#    SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 0            0.0  ...           No  No phone service             DSL
# ...

# %%
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus["TotalCharges"]=cus["TotalCharges"].fillna(0)
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges         0
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus["SeniorCitizen"]=cus["SeniorCitizen"].fillna(0)
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges         0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus[cus["MonthlyCharges"]==0.0].head(50)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, customerID, tenure, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, gender, SeniorCitizen, Partner, Dependents, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Churn]
# Index: []
#
# [0 rows x 22 columns]

# %%
cus.isnull().sum()
# Out:
# Unnamed: 0           0
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges         0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
cus[cus["MonthlyCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 53           54  6652-YFFJO     11  Month-to-month              Yes
# 91           92  5919-TMRGD    One  Month-to-month              Yes
# 104         105  9392-XBGTD     27        Two year               No
# 133         134  4682-BLBUC     44        One year              Yes
# 134         135  3258-ZKPAI     72        Two year              Yes
# 170         171  4018-PPNDW     61        Two year              Yes
# 172         173  1116-FRYVH     48        Two year               No
# 176         177  6762-NSODU     46        Two year               No
# 184         185  3621-CEOVK     14  Month-to-month              Yes
# 250         251  5192-EBGOV    One  Month-to-month              Yes
#
#                  PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 53            Electronic check             NaN        716.10  Female
# 91            Electronic check             NaN         79.35  Female
# ...

# %%
cus.loc[(cus["Contract"]=="One year")&
        (cus["PaperlessBilling"].isin(["Yes"]))&
        (cus["PhoneService"].isin(["Yes"]))&
        (cus["MultipleLines"].isin(["No"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      7
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus.loc[(cus["Contract"]=="One year")&
        (cus["PaperlessBilling"].isin(["No"]))&
        (cus["PhoneService"].isin(["No"]))&
        (cus["MultipleLines"].isin(["Yes"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      7
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["PhoneService"]=="Yes"].head(50)
# Out:
#     Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 1            2  2359-QWQUL     39        One year              Yes
# 2            3  6598/RFFVI      2        One year               No
# 3            4  IXSTS-8780      6  Month-to-month              Yes
# 4            5  2674/MIAHT   Four  Month-to-month              Yes
# 5            6  6077-BDPXA      3  Month-to-month              Yes
# 6            7  7929/SKFGK     70        Two year               No
# 7            8  7547-EKNFS     42  Month-to-month              Yes
# 8            9  5854-KSRBJ     70        Two year               No
# 9           10  5054-IEXZT    One  Month-to-month              Yes
# 10          11  1877-HKBQX     11        One year              Yes
# 11          12  7235-NXZCP      2  Month-to-month              Yes
# 12          13  3325-FUYCG     28        One year               No
# 13          14  2452-MRMZF     72        Two year              Yes
# ...

# %%
cus[cus["PaperlessBilling"]=="Yes"].head(50)
# Out:
#     Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 1            2  2359-QWQUL     39        One year              Yes
# 3            4  IXSTS-8780      6  Month-to-month              Yes
# 4            5  2674/MIAHT   Four  Month-to-month              Yes
# 5            6  6077-BDPXA      3  Month-to-month              Yes
# 7            8  7547-EKNFS     42  Month-to-month              Yes
# 9           10  5054-IEXZT    One  Month-to-month              Yes
# 10          11  1877-HKBQX     11        One year              Yes
# 11          12  7235-NXZCP      2  Month-to-month              Yes
# 13          14  2452-MRMZF     72        Two year              Yes
# 16          17  2612-PHGOX     64        Two year              Yes
# 17          18  6874-SGLHU     30        One year              Yes
# 18          19  9588-YRFHY     49        Two year              Yes
# 19          20  6513-EECDB    One  Month-to-month              Yes
# ...

# %%
cus[cus["MultipleLines"]=="Yes"].head(50)
# Out:
#      Unnamed: 0  customerID tenure        Contract PaperlessBilling  \
# 3             4  IXSTS-8780      6  Month-to-month              Yes
# 4             5  2674/MIAHT   Four  Month-to-month              Yes
# 6             7  7929/SKFGK     70        Two year               No
# 7             8  7547-EKNFS     42  Month-to-month              Yes
# 8             9  5854-KSRBJ     70        Two year               No
# 11           12  7235-NXZCP      2  Month-to-month              Yes
# 12           13  3325-FUYCG     28        One year               No
# 13           14  2452-MRMZF     72        Two year              Yes
# 16           17  2612-PHGOX     64        Two year              Yes
# 19           20  6513-EECDB    One  Month-to-month              Yes
# 25           26  9762-YAQAA     39        One year               No
# 26           27  1114-CENIM     54  Month-to-month              Yes
# 27           28  1090-PYKCI     69        One year              Yes
# ...

# %%
cus.loc[(cus["Contract"]=="Month-to-month")&
        (cus["PaperlessBilling"].isin(["Yes"]))&
        (cus["PhoneService"].isin(["Yes"]))&
        (cus["MultipleLines"].isin(["Yes"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      5
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["MonthlyCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure  Contract PaperlessBilling  \
# 104         105  9392-XBGTD     27  Two year               No
# 134         135  3258-ZKPAI     72  Two year              Yes
# 170         171  4018-PPNDW     61  Two year              Yes
# 172         173  1116-FRYVH     48  Two year               No
# 176         177  6762-NSODU     46  Two year               No
#
#                  PaymentMethod MonthlyCharges  TotalCharges  gender  \
# 104               Mailed check            NaN        581.85    Male
# 134  Bank transfer (automatic)            NaN       8337.45    Male
# 170               Mailed check            NaN       1551.60  Female
# 172               Mailed check            NaN       1978.65  Female
# 176    Credit card (automatic)            NaN        958.15  Female
#
#      SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 104            0.0  ...          Yes                No              No
# ...

# %%
cus.loc[(cus["Contract"]=="Two year")&
        (cus["PaperlessBilling"].isin(["No"]))&
        (cus["PhoneService"].isin(["Yes"]))&
        (cus["MultipleLines"].isin(["No"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      3
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["MonthlyCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure  Contract PaperlessBilling  \
# 134         135  3258-ZKPAI     72  Two year              Yes
# 170         171  4018-PPNDW     61  Two year              Yes
# 172         173  1116-FRYVH     48  Two year               No
#
#                  PaymentMethod MonthlyCharges  TotalCharges  gender  \
# 134  Bank transfer (automatic)            NaN       8337.45    Male
# 170               Mailed check            NaN       1551.60  Female
# 172               Mailed check            NaN       1978.65  Female
#
#      SeniorCitizen  ... PhoneService     MultipleLines InternetService  \
# 134            0.0  ...          Yes               Yes     Fiber optic
# 170            0.0  ...          Yes               Yes              No
# 172            0.0  ...           No  No phone service             DSL
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 134                  Yes                  Yes                  Yes
# ...

# %%
cus.loc[(cus["Contract"]=="Two year")&
        (cus["PaperlessBilling"].isin(["Yes"]))&
        (cus["PhoneService"].isin(["Yes"]))&
        (cus["MultipleLines"].isin(["Yes"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      1
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64

# %%
cus[cus["MonthlyCharges"].isna()].head(50)
# Out:
#      Unnamed: 0  customerID tenure  Contract PaperlessBilling PaymentMethod  \
# 172         173  1116-FRYVH     48  Two year               No  Mailed check
#
#     MonthlyCharges  TotalCharges  gender  SeniorCitizen  ... PhoneService  \
# 172            NaN       1978.65  Female            0.0  ...           No
#
#         MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 172  No phone service             DSL            Yes          Yes
#
#     DeviceProtection TechSupport StreamingTV StreamingMovies Churn
# 172               No         Yes          No              No    No
#
# [1 rows x 22 columns]

# %%
cus.loc[(cus["Contract"]=="Two year")&
        (cus["PaperlessBilling"].isin(["No"]))&
        (cus["PhoneService"].isin(["No"]))&
        (cus["MultipleLines"].isin(["No phone service"])),"MonthlyCharges"]="0.0"
cus
cus.isnull().sum()
# Out:
# Unnamed: 0          0
# customerID          0
# tenure              0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Churn               0
# dtype: int64
